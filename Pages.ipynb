# %%
import pandas as pd
import numpy as np

# %%
#Read data, grab only the first table, not the date table
ua_file = pd.read_csv('Acura_UA_Pages.csv', header = 6, thousands=',')
n_values = np.logical_not(ua_file.isnull()).sum(axis=1)
cut_off = n_values[n_values == 0].index[0]
ua_file = ua_file[:cut_off -1]
ua_file['Users'] = ua_file['Users'].str.replace(',','')
g4_file = pd.read_csv('Acura_GA4_Pages.csv', header = 6, thousands=',')
g4_file = g4_file[['Page path + query string', 'Total users', 'Sessions']]
g4_file.rename(columns={'Page path + query string': 'Page', 'Total users': 'Users'}, inplace = True)

#Add data source column

ua_file['data_source'] = 'UA'
g4_file['data_source'] = 'G4'

#Append data, reset index
data = ua_file.append(g4_file).reset_index()
data.drop(columns={'index'}, inplace = True)
data
# Out:
#                                                     Page  Users  Sessions  \
# 0                                                      /  28273   32604.0
# 1                                        /buildyouracura  19486    8758.0
# 2                                                   /mdx  16009   13302.0
# 3                                /buildyouracura/colours  15318      96.0
# 4                                                   /rdx  12694    9230.0
# ...                                                  ...    ...       ...
# 52256  /mdx?gclid=EAIaIQobChMIsbTixt-98gIVyR-tBh2pnAa...      1       1.0
# 52257  /mdx?gclid=EAIaIQobChMIsba-5-y_8gIVuz6tBh0Zkgv...      1       1.0
# 52258  /mdx?gclid=EAIaIQobChMIsfDctsHD8gIV2CCtBh3Rjwc...      1       1.0
# 52259  /mdx?gclid=EAIaIQobChMIsfKcsK7A8gIVUBmtBh1Z2Qc...      1       0.0
# 52260  /mdx?gclid=EAIaIQobChMIsfb02LLA8gIVEQ_nCh27FA3...      1       1.0
#
#       data_source
# 0              UA
# 1              UA
# 2              UA
# 3              UA
# 4              UA
# ...           ...
# 52256          G4
# 52257          G4
# 52258          G4
# 52259          G4
# 52260          G4
#
# [52261 rows x 4 columns]

# %%
#Create pivot table
piv = pd.pivot_table(data, values = ['Users', 'Sessions'], index = 'Page', columns = 'data_source', aggfunc = {'Users':sum, 'Sessions':sum})
piv.columns = [c[1] + ' ' +  c[0] for c in piv.columns]
piv['G4 Users'] = piv['G4 Users'].astype('float')
piv['UA Users'] = piv['UA Users'].astype('float')

#Add Difference, Variance Columns
piv['Session Difference'] = piv['G4 Sessions'] - piv['UA Sessions']
piv['Session Variance (%)'] = (piv['G4 Sessions'] - piv['UA Sessions'])/ piv['UA Sessions']
piv['Users Difference'] = piv['G4 Users'] - piv['UA Users']
piv['Users Variance (%)'] = (piv['G4 Users'] - piv['UA Users'])/ piv['UA Users']
piv = piv[[ 'G4 Users', 'UA Users', 'Users Difference', 'Users Variance (%)', 'G4 Sessions', 'UA Sessions', 'Session Difference', 'Session Variance (%)']]
piv.sort_values(by = ['G4 Users'], ascending = False, inplace = True)

# %%
piv
# Out:
#                                                     G4 Users  UA Users  \
# Page
# /                                                    20457.0   28273.0
# /buildyouracura/colours                              15621.0   15318.0
# /buildyouracura/accessories                          12710.0   12551.0
# /buildyouracura/trims                                12634.0   12398.0
# /buildyouracura/models                               11996.0   11888.0
# ...                                                      ...       ...
# /zh/zh/zh/mdx/accessories                                NaN       1.0
# /zh/zh/zh/newsdetails/nca/en/news/release/Acura...       NaN       1.0
# /zh/zh/zh/sitemap                                        NaN       1.0
# /zh/zh/zh/tlx/packages                                   NaN       1.0
# /zh/zh/zh/undefined/zh/zh/zh/undefined/zh/zh/zh/         NaN       1.0
#
#                                                     Users Difference  \
# Page
# /                                                            -7816.0
# /buildyouracura/colours                                        303.0
# /buildyouracura/accessories                                    159.0
# /buildyouracura/trims                                          236.0
# /buildyouracura/models                                         108.0
# ...                                                              ...
# /zh/zh/zh/mdx/accessories                                        NaN
# /zh/zh/zh/newsdetails/nca/en/news/release/Acura...               NaN
# /zh/zh/zh/sitemap                                                NaN
# /zh/zh/zh/tlx/packages                                           NaN
# /zh/zh/zh/undefined/zh/zh/zh/undefined/zh/zh/zh/                 NaN
#
#                                                     Users Variance (%)  \
# Page
# /                                                            -0.276447
# /buildyouracura/colours                                       0.019781
# /buildyouracura/accessories                                   0.012668
# /buildyouracura/trims                                         0.019035
# /buildyouracura/models                                        0.009085
# ...                                                                ...
# /zh/zh/zh/mdx/accessories                                          NaN
# /zh/zh/zh/newsdetails/nca/en/news/release/Acura...                 NaN
# /zh/zh/zh/sitemap                                                  NaN
# /zh/zh/zh/tlx/packages                                             NaN
# /zh/zh/zh/undefined/zh/zh/zh/undefined/zh/zh/zh/                   NaN
#
#                                                     G4 Sessions  UA Sessions  \
# Page
# /                                                       21883.0      32604.0
# /buildyouracura/colours                                    27.0         96.0
# /buildyouracura/accessories                                26.0         32.0
# /buildyouracura/trims                                      48.0        502.0
# /buildyouracura/models                                     71.0         73.0
# ...                                                         ...          ...
# /zh/zh/zh/mdx/accessories                                   NaN          0.0
# /zh/zh/zh/newsdetails/nca/en/news/release/Acura...          NaN          1.0
# /zh/zh/zh/sitemap                                           NaN          0.0
# /zh/zh/zh/tlx/packages                                      NaN          0.0
# /zh/zh/zh/undefined/zh/zh/zh/undefined/zh/zh/zh/            NaN          1.0
#
#                                                     Session Difference  \
# Page
# /                                                             -10721.0
# /buildyouracura/colours                                          -69.0
# /buildyouracura/accessories                                       -6.0
# /buildyouracura/trims                                           -454.0
# /buildyouracura/models                                            -2.0
# ...                                                                ...
# /zh/zh/zh/mdx/accessories                                          NaN
# /zh/zh/zh/newsdetails/nca/en/news/release/Acura...                 NaN
# /zh/zh/zh/sitemap                                                  NaN
# /zh/zh/zh/tlx/packages                                             NaN
# /zh/zh/zh/undefined/zh/zh/zh/undefined/zh/zh/zh/                   NaN
#
#                                                     Session Variance (%)
# Page
# /                                                              -0.328825
# /buildyouracura/colours                                        -0.718750
# /buildyouracura/accessories                                    -0.187500
# /buildyouracura/trims                                          -0.904382
# /buildyouracura/models                                         -0.027397
# ...                                                                  ...
# /zh/zh/zh/mdx/accessories                                            NaN
# /zh/zh/zh/newsdetails/nca/en/news/release/Acura...                   NaN
# /zh/zh/zh/sitemap                                                    NaN
# /zh/zh/zh/tlx/packages                                               NaN
# /zh/zh/zh/undefined/zh/zh/zh/undefined/zh/zh/zh/                     NaN
#
# [50687 rows x 8 columns]

# %%
piv.to_excel('Acura_Pivot_Page.xlsx')
